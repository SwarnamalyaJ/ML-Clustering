# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
dataset = pd.read_csv('Mall_Customers.csv')

# %%
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
X = dataset.iloc[:, 3:5].values

# %%
X
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
from sklearn.cluster import AgglomerativeClustering
agg_clustering = AgglomerativeClustering(n_clusters=5)
y_agg = agg_clustering.fit_predict(X)

# %%
supervised_agg = dataset.copy()
supervised_agg['Cluster_group'] = y_agg
supervised_agg.to_csv("cluster_agglomerative.csv", index=False)

# %%
# Visualize the clusters
plt.figure(figsize=(10, 6))
plt.scatter(X[y_agg == 0, 0], X[y_agg == 0, 1], s=50, c='blue', label='Cluster 1')
plt.scatter(X[y_agg == 1, 0], X[y_agg == 1, 1], s=50, c='green', label='Cluster 2')
plt.scatter(X[y_agg == 2, 0], X[y_agg == 2, 1], s=50, c='orange', label='Cluster 3')
plt.scatter(X[y_agg == 3, 0], X[y_agg == 3, 1], s=50, c='red', label='Cluster 4')
plt.scatter(X[y_agg == 4, 0], X[y_agg == 4, 1], s=50, c='purple', label='Cluster 5')

plt.title('Agglomerative Clustering')
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.legend()
plt.show()

# %%
facet = sns.lmplot(data=supervised_agg, x=supervised_agg.columns[3], y=supervised_agg.columns[4], hue='Cluster_group',
                   fit_reg=False, legend=True, legend_out=True)
# Out:
# C:\Users\Malya\anaconda3\envs\aimlds\lib\site-packages\seaborn\regression.py:598: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
